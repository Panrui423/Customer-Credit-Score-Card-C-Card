# %%
import pandas as pd
import numpy as np

# %%
f = open(r'C:\Users\meizihang\Documents\ALLCODE\课程资料\七月在线\金融风控实战\02 树模型与规则挖掘\星座生肖单变量分析\ft_zodiac.txt', encoding='utf-8')
ft_zodiac = pd.read_csv(f)  
print(ft_zodiac.shape)
ft_zodiac.head()
# Out:
# (23519, 4)
#    0            order_id chinese_zodiac zodiac
# 0  0  100000081567592448              狗    处女座
# 1  0  100000467565182976              牛    双子座
# 2  0  100000530945323008              羊    射手座
# 3  0  100000556765458432              鼠    摩羯座
# 4  0  100000598171623424              虎    水瓶座

# %% [markdown]
# pd15作为好坏的分割节点。>15 为坏人，<15为好人？
#
# 15天以上的人为坏，5天以内的人为好。因为不太好找界限，14天和15天其实没太多区别，所以我们尝试在这个区间挖一个洞，把这部分人去掉，2即代表这群人

# %%
l = open(r'C:\Users\meizihang\Documents\ALLCODE\课程资料\七月在线\金融风控实战\02 树模型与规则挖掘\星座生肖单变量分析\zodiac_label.txt')
zodiac_label=pd.read_csv(l)

ft_label = zodiac_label[zodiac_label['label'] != 2]  # 0为好人，1为坏人
ft_label.head()
# Out:
#              order_id  overdue_days  repay_time  label
# 0  100000081567592448             0  2018-07-09      0
# 1  100000467565182976             1  2018-07-09      0
# 2  100000530945323008             0  2018-07-09      0
# 3  100000556765458432             0  2018-07-09      0
# 4  100000598171623424             0  2018-07-09      0

# %%
data = pd.merge(ft_label,ft_zodiac,on = 'order_id',how = 'inner')
data.head()
# Out:
#              order_id  overdue_days  repay_time  label  0 chinese_zodiac  \
# 0  100000081567592448             0  2018-07-09      0  0              狗
# 1  100000467565182976             1  2018-07-09      0  0              牛
# 2  100000530945323008             0  2018-07-09      0  0              羊
# 3  100000556765458432             0  2018-07-09      0  0              鼠
# 4  100000598171623424             0  2018-07-09      0  0              虎
#
#   zodiac
# 0    处女座
# 1    双子座
# 2    射手座
# 3    摩羯座
# 4    水瓶座

# %% [markdown]
# badrate = bad/toal

# %%
zodiac_list = set(data.zodiac)    # set用于去重
chinese_zodiac_list = set(data.chinese_zodiac)

# %%
zodiac_list
# Out:
# {'双子座',
#  '双鱼座',
#  '处女座',
#  '天秤座',
#  '天蝎座',
#  '射手座',
#  '巨蟹座',
#  '摩羯座',
#  '水瓶座',
#  '狮子座',
#  '白羊座',
#  '金牛座'}

# %%
chinese_zodiac_list
# Out:
# {'兔', '牛', '狗', '猪', '猴', '羊', '虎', '蛇', '马', '鸡', '鼠', '龙'}

# %%
#星座
zodiac_badrate = {}
for x in zodiac_list:
    
    a = data[data.zodiac == x]
    
    bad = a[a.label == 1]['label'].count()
    good = a[a.label == 0]['label'].count()
    
    zodiac_badrate[x] = bad/(bad+good)

# %%
zodiac_badrate
# Out:
# {'天秤座': 0.12461252324860508,
#  '天蝎座': 0.12005028284098052,
#  '摩羯座': 0.12920489296636087,
#  '双鱼座': 0.14873646209386282,
#  '狮子座': 0.12760416666666666,
#  '水瓶座': 0.140117994100295,
#  '双子座': 0.1312410841654779,
#  '巨蟹座': 0.1408351026185421,
#  '射手座': 0.14480286738351256,
#  '处女座': 0.13035143769968052,
#  '金牛座': 0.12259059367771781,
#  '白羊座': 0.13455414012738853}

# %%
f = zip(zodiac_badrate.keys(),zodiac_badrate.values())  # zip() 函数用于将可迭代的对象作为参数，将对象中对应的元素打包成一个个元组，然后返回由这些元组组成的列表。
f = sorted(f, key = lambda x : x[1], reverse = True )  # lambda argument_list:expersion
zodiac_badrate = pd.DataFrame(f)
zodiac_badrate.columns = pd.Series(['星座','badrate'])
zodiac_badrate
# Out:
#      星座   badrate
# 0   双鱼座  0.148736
# 1   射手座  0.144803
# 2   巨蟹座  0.140835
# 3   水瓶座  0.140118
# 4   白羊座  0.134554
# 5   双子座  0.131241
# 6   处女座  0.130351
# 7   摩羯座  0.129205
# 8   狮子座  0.127604
# 9   天秤座  0.124613
# 10  金牛座  0.122591
# 11  天蝎座  0.120050

# %%
from pyecharts import Line
x = zodiac_badrate['星座']
y = zodiac_badrate['badrate']
line = Line('星座')
line.add(1,x,y)
# Out:
# ERROR:lml.utils:failed to import pyecharts_snapshot
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\lml\utils.py", line 43, in do_import
#     plugin_module = __import__(plugin_module_name)
# ModuleNotFoundError: No module named 'pyecharts_snapshot'
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="875a5ca8c84041bcb7f6b3a84cfaab79" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_875a5ca8c84041bcb7f6b3a84cfaab79 = echarts.init(document.getElementById('875a5ca8c84041bcb7f6b3a84cfaab79'), 'light', {renderer: 'canvas'});
#
# var option_875a5ca8c84041bcb7f6b3a84cfaab79 = {
#     "title": [
#         {
#             "text": "\u661f\u5ea7",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6100021,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": 1,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u53cc\u9c7c\u5ea7",
#                     0.14873646209386282
#                 ],
#                 [
#                     "\u5c04\u624b\u5ea7",
#                     0.14480286738351256
#                 ],
#                 [
#                     "\u5de8\u87f9\u5ea7",
#                     0.1408351026185421
#                 ],
#                 [
#                     "\u6c34\u74f6\u5ea7",
#                     0.140117994100295
#                 ],
#                 [
#                     "\u767d\u7f8a\u5ea7",
#                     0.13455414012738853
#                 ],
#                 [
#                     "\u53cc\u5b50\u5ea7",
#                     0.1312410841654779
#                 ],
#                 [
#                     "\u5904\u5973\u5ea7",
#                     0.13035143769968052
#                 ],
#                 [
#                     "\u6469\u7faf\u5ea7",
#                     0.12920489296636087
#                 ],
#                 [
#                     "\u72ee\u5b50\u5ea7",
#                     0.12760416666666666
#                 ],
#                 [
#                     "\u5929\u79e4\u5ea7",
#                     0.12461252324860508
#                 ],
#                 [
#                     "\u91d1\u725b\u5ea7",
#                     0.12259059367771781
#                 ],
#                 [
#                     "\u5929\u874e\u5ea7",
#                     0.12005028284098052
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6100021
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 1
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u53cc\u9c7c\u5ea7",
#                 "\u5c04\u624b\u5ea7",
#                 "\u5de8\u87f9\u5ea7",
#                 "\u6c34\u74f6\u5ea7",
#                 "\u767d\u7f8a\u5ea7",
#                 "\u53cc\u5b50\u5ea7",
#                 "\u5904\u5973\u5ea7",
#                 "\u6469\u7faf\u5ea7",
#                 "\u72ee\u5b50\u5ea7",
#                 "\u5929\u79e4\u5ea7",
#                 "\u91d1\u725b\u5ea7",
#                 "\u5929\u874e\u5ea7"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_875a5ca8c84041bcb7f6b3a84cfaab79.setOption(option_875a5ca8c84041bcb7f6b3a84cfaab79);
#
#     });
# </script>

# %%
#生肖
chinese_zodiac_badrate = {}
for x in chinese_zodiac_list:
    
    a = data[data.chinese_zodiac == x]
    
    bad = a[a.label == 1]['label'].count()
    good = a[a.label == 0]['label'].count()
    
    chinese_zodiac_badrate[x] = bad/(bad+good)

# %%
chinese_zodiac_badrate
# Out:
# {'鼠': 0.1340602950609365,
#  '兔': 0.1502843216896832,
#  '虎': 0.15165876777251186,
#  '龙': 0.1439084219133279,
#  '鸡': 0.12846998063266624,
#  '狗': 0.11052009456264776,
#  '猴': 0.12008141112618724,
#  '猪': 0.14269406392694065,
#  '马': 0.12053872053872054,
#  '蛇': 0.12789827973074047,
#  '牛': 0.1578112609040444,
#  '羊': 0.11335403726708075}

# %%
f = zip(chinese_zodiac_badrate.keys(),chinese_zodiac_badrate.values())
f = sorted(f,key = lambda x : x[1],reverse = True )
chinese_zodiac_badrate = pd.DataFrame(f)
chinese_zodiac_badrate.columns = pd.Series(['生肖','badrate'])
chinese_zodiac_badrate
# Out:
#    生肖   badrate
# 0   牛  0.157811
# 1   虎  0.151659
# 2   兔  0.150284
# 3   龙  0.143908
# 4   猪  0.142694
# 5   鼠  0.134060
# 6   鸡  0.128470
# 7   蛇  0.127898
# 8   马  0.120539
# 9   猴  0.120081
# 10  羊  0.113354
# 11  狗  0.110520

# %%
from pyecharts import Line
x = chinese_zodiac_badrate['生肖']
y = chinese_zodiac_badrate['badrate']
line = Line('生肖')
line.add(1,x,y)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="be80890ea8034887b01d4b1f497cd532" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_be80890ea8034887b01d4b1f497cd532 = echarts.init(document.getElementById('be80890ea8034887b01d4b1f497cd532'), 'light', {renderer: 'canvas'});
#
# var option_be80890ea8034887b01d4b1f497cd532 = {
#     "title": [
#         {
#             "text": "\u751f\u8096",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 512197,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": 1,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u725b",
#                     0.1578112609040444
#                 ],
#                 [
#                     "\u864e",
#                     0.15165876777251186
#                 ],
#                 [
#                     "\u5154",
#                     0.1502843216896832
#                 ],
#                 [
#                     "\u9f99",
#                     0.1439084219133279
#                 ],
#                 [
#                     "\u732a",
#                     0.14269406392694065
#                 ],
#                 [
#                     "\u9f20",
#                     0.1340602950609365
#                 ],
#                 [
#                     "\u9e21",
#                     0.12846998063266624
#                 ],
#                 [
#                     "\u86c7",
#                     0.12789827973074047
#                 ],
#                 [
#                     "\u9a6c",
#                     0.12053872053872054
#                 ],
#                 [
#                     "\u7334",
#                     0.12008141112618724
#                 ],
#                 [
#                     "\u7f8a",
#                     0.11335403726708075
#                 ],
#                 [
#                     "\u72d7",
#                     0.11052009456264776
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 512197
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 1
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u725b",
#                 "\u864e",
#                 "\u5154",
#                 "\u9f99",
#                 "\u732a",
#                 "\u9f20",
#                 "\u9e21",
#                 "\u86c7",
#                 "\u9a6c",
#                 "\u7334",
#                 "\u7f8a",
#                 "\u72d7"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_be80890ea8034887b01d4b1f497cd532.setOption(option_be80890ea8034887b01d4b1f497cd532);
#
#     });
# </script>
